# %%
import pandas as pd

# %%
data = pd.read_csv('Resources/city_data.csv')
data.drop(columns='Pressure (hPa)',inplace=True)
data.rename(columns={
    'Temperature (F)':'Temp (F)',
    'Min Temperature (F)': 'Min Temp (F)',
    'Max Temperature (F)': 'Max Temp (F)',
    'Latitude':'Lat',
    'Longitude':'Lon'
}, inplace=True)

# %%
data
# Out:
#               City Country      Lat       Lon  Temp (F)  Min Temp (F)  \
# 0          rikitea      PF -23.1203 -134.9692     73.98         73.98
# 1          ushuaia      AR -54.8000  -68.3000     42.46         42.46
# 2     ponta do sol      PT  32.6667  -17.1000     74.28         73.13
# 3            never      RU  53.9833  124.1667     59.14         59.14
# 4    mar del plata      AR -38.0023  -57.5575     45.77         44.62
# ..             ...     ...      ...       ...       ...           ...
# 546  sioux lookout      CA  50.1001  -91.9170     80.67         80.67
# 547      la romana      DO  18.4273  -68.9728     91.76         87.53
# 548     kirksville      US  40.1948  -92.5833     91.36         89.55
# 549          mpika      ZM -11.8343   31.4529     54.52         54.52
# 550       bardiyah      LY  31.7561   25.0865     81.34         81.34
#
#      Max Temp (F)  Humidity (%)  Cloudiness (%)  Wind Speed (mph)  Date (UTC)
# ...

# %%
data.to_html('data_table.html',index=False,justify='left')
